# %% [markdown]
# ### Import reviews

# %%
# %load_ext autoreload
# %autoreload 2

import progressbar

# %%
import pickle

DATA_FILE1 = 'data/data.pkl'
DATA_FILE2 = 'data/labels.pkl'
DATA_FILE3 = 'data/pos_adjectives_list.pkl'
DATA_FILE4 = 'data/neu_adjectives_list.pkl'
DATA_FILE5 = 'data/neg_adjectives_list.pkl'

with open(DATA_FILE1, 'rb') as f:
    reviews = pickle.load(f)
    
with open(DATA_FILE2, 'rb') as f:
    labels = pickle.load(f)
   
entity_names = ['X', 'Y', 'Z']

# %%
from babble.babbler import BabbleStream

babbler = BabbleStream(reviews,labels,balanced=True, shuffled=True, seed=456)
# Out:
# Grammar construction complete.

# %%
from babble.utils import display_candidate

candidate = babbler.next()
print(candidate)
print(candidate.text)
print(candidate.entity_positions)
# Out:
# RelationMention(doc_id=917: entities=("bar"(13:16), "water"(33:38), "place"(71:76))
# what kind of bar won't serve you water it 120 degrees outside.... this place should get shutdown.... i spent $100 and they won't give me water to sober up
# [(13, 16), (33, 38), (71, 76)]

# %%
import re

def get_words_before(quantity,sentence,entity):
    sentence = re.sub(r'[^\w\s]','',sentence)
    words = sentence.split()
    if entity in words:
        index = words.index(entity)
        before = index - min(index, quantity)
        return ' '.join(map(str, words[before:index]))

# %%
import re

def get_words_after(quantity,sentence,entity):
    sentence = re.sub(r'[^\w\s]','',sentence)
    words = sentence.split()
    if entity in words:
        index = words.index(entity) +1
        after = index + min(index, quantity)
        return ' '.join(map(str, words[index:after]))

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()

pos_adjectives_list=[]
neu_adjectives_list=[]
neg_adjectives_list=[]

def check_sentiment_adjective(adjective):
    if (sid.polarity_scores(adjective)['compound']) >= 0.1:
        pos_adjectives_list.append(adjective)
        return 'positive'
    elif (sid.polarity_scores(adjective)['compound']) <= -0.1:
        neg_adjectives_list.append(adjective)
        return 'negative'
    else:
        neu_adjectives_list.append(adjective)
        return 'neutral'

# %%
def check_adjectives_before_pos(sentence,entity):
    words = get_words_before(2,sentence,entity)
    if words == None or len(words.split(" ")) == 0:
        return None
    else:
        spacy_nlp = spacy.load('en_core_web_sm')
        doc = spacy_nlp(words)
        for token in doc:
            if token.pos_ == 'ADJ':
                return token.text
                break

# %%
def check_adjectives_after_verb(sentence,entity):
    words = get_words_after(3,sentence,entity)
    if words == None or len(words.split(" ")) < 3:
        return None
    else:
        spacy_nlp = spacy.load('en_core_web_sm')
        doc = spacy_nlp(words)
        if doc[0].pos_ == 'VERB' and (doc[1].pos_ == 'ADJ' or doc[2].pos_ == 'ADJ'):
            return doc[1].text

# %%
import spacy

spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS

print('spaCy Version: %s' % (spacy.__version__))
spacy_nlp = spacy.load('en_core_web_sm')
# Out:
# spaCy Version: 2.1.8

# %%
from babble import Explanation

explanations = []
index = 1


for candidate,label in progressbar.progressbar(zip(reviews[0],labels[0])):
#    print(candidate.text)
    condition = ''
    for entity,name in zip(candidate.entities,entity_names):
#        print(entity.entity)
        adjective = check_adjectives_after_verb(candidate.text,entity.entity)
        if adjective != None:
            sentiment_value = check_sentiment_adjective(adjective)
            condition = condition + 'A ' + sentiment_value + ' word is within 3 words to the right of ' + name + ' and '
        else:
            adjective = check_adjectives_before_pos(candidate.text,entity.entity)
            if adjective != None:
                sentiment_value = check_sentiment_adjective(adjective)
                condition = condition + 'A ' + sentiment_value + ' word is within 2 words to the left of ' + name + ' and '
    condition = condition[:-4]
    if condition != '':
        explanation = Explanation(
        name='LF_' + str(index),
        label=label,
        condition=condition,
        candidate=candidate,
        )
        explanations.append(explanation)
        index = index + 1
#            print(str(explanation).upper())
# Out:
# | |                  #                              | 869 Elapsed Time: 0:12:32

# %%
print(explanations)
# Out:
# [Explanation(LF_1: 1, "A neutral word is within 2 words to the left of X and A negative word is within 2 words to the left of Y"), Explanation(LF_2: 1, "A negative word is within 2 words to the left of X and A neutral word is within 3 words to the right of Y"), Explanation(LF_3: 1, "A neutral word is within 2 words to the left of Y"), Explanation(LF_4: 1, "A neutral word is within 3 words to the right of Z"), Explanation(LF_5: 1, "A positive word is within 2 words to the left of X and A neutral word is within 3 words to the right of Y"), Explanation(LF_6: 1, "A neutral word is within 3 words to the right of Y"), Explanation(LF_7: 1, "A neutral word is within 2 words to the left of Y"), Explanation(LF_8: 1, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Z"), Explanation(LF_9: 1, "A negative word is within 2 words to the left of X"), Explanation(LF_10: 1, "A positive word is within 2 words to the left of X"), Explanation(LF_11: 1, "A negative word is within 2 words to the left of X and A neutral word is within 3 words to the right of Y and A neutral word is within 2 words to the left of Z"), Explanation(LF_12: 1, "A negative word is within 2 words to the left of X and A negative word is within 2 words to the left of Y"), Explanation(LF_13: 1, "A neutral word is within 2 words to the left of X and A neutral word is within 3 words to the right of Y"), Explanation(LF_14: 1, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"), Explanation(LF_15: 1, "A positive word is within 2 words to the left of X"), Explanation(LF_16: 1, "A negative word is within 2 words to the left of X"), Explanation(LF_17: 1, "A positive word is within 3 words to the right of X and A negative word is within 2 words to the left of Z"), Explanation(LF_18: 1, "A negative word is within 2 words to the left of Z"), Explanation(LF_19: 1, "A negative word is within 2 words to the left of Z"), Explanation(LF_20: 1, "A negative word is within 2 words to the left of X"), Explanation(LF_21: 1, "A negative word is within 2 words to the left of X"), Explanation(LF_22: 1, "A neutral word is within 3 words to the right of Z"), Explanation(LF_23: 1, "A neutral word is within 3 words to the right of X"), Explanation(LF_24: 1, "A negative word is within 2 words to the left of X and A negative word is within 2 words to the left of Y"), Explanation(LF_25: 1, "A neutral word is within 2 words to the left of X and A negative word is within 2 words to the left of Z"), Explanation(LF_26: 1, "A neutral word is within 2 words to the left of Y"), Explanation(LF_27: 1, "A negative word is within 2 words to the left of X and A negative word is within 2 words to the left of Z"), Explanation(LF_28: 1, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"), Explanation(LF_29: 1, "A neutral word is within 3 words to the right of Y"), Explanation(LF_30: 1, "A negative word is within 2 words to the left of Y"), Explanation(LF_31: 1, "A negative word is within 2 words to the left of X"), Explanation(LF_32: 1, "A neutral word is within 2 words to the left of Y"), Explanation(LF_33: 1, "A negative word is within 2 words to the left of X"), Explanation(LF_34: 1, "A negative word is within 2 words to the left of Y"), Explanation(LF_35: 1, "A negative word is within 2 words to the left of Y and A negative word is within 2 words to the left of Z"), Explanation(LF_36: 1, "A negative word is within 2 words to the left of X and A negative word is within 2 words to the left of Y"), Explanation(LF_37: 1, "A negative word is within 2 words to the left of Z"), Explanation(LF_38: 1, "A neutral word is within 2 words to the left of Z"), Explanation(LF_39: 1, "A neutral word is within 3 words to the right of X and A positive word is within 2 words to the left of Z"), Explanation(LF_40: 1, "A neutral word is within 2 words to the left of X and A neutr ...

# %%
pos_adjectives_list = list(dict.fromkeys(pos_adjectives_list))
neu_adjectives_list = list(dict.fromkeys(neu_adjectives_list))
neg_adjectives_list = list(dict.fromkeys(neg_adjectives_list))

# %%
with open(DATA_FILE3, 'wb') as f:
    pickle.dump(pos_adjectives_list,f)
    
with open(DATA_FILE4, 'wb') as f:
    pickle.dump(neu_adjectives_list,f)

with open(DATA_FILE5, 'wb') as f:
    pickle.dump(neg_adjectives_list,f)

# %%
from babble.utils import ExplanationIO

FILE = "data/my_explanations.tsv"
exp_io = ExplanationIO()
exp_io.write(explanations, FILE)
exp_io.read(FILE)
# Out:
# Wrote 595 explanations to data/my_explanations.tsv
# Read 595 explanations from data/my_explanations.tsv
# [Explanation(LF_1: 1, "A neutral word is within 2 words to the left of X and A negative word is within 2 words to the left of Y"),
#  Explanation(LF_2: 1, "A negative word is within 2 words to the left of X and A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_3: 1, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_4: 1, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_5: 1, "A positive word is within 2 words to the left of X and A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_6: 1, "A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_7: 1, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_8: 1, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_9: 1, "A negative word is within 2 words to the left of X"),
#  Explanation(LF_10: 1, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_11: 1, "A negative word is within 2 words to the left of X and A neutral word is within 3 words to the right of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_12: 1, "A negative word is within 2 words to the left of X and A negative word is within 2 words to the left of Y"),
#  Explanation(LF_13: 1, "A neutral word is within 2 words to the left of X and A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_14: 1, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_15: 1, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_16: 1, "A negative word is within 2 words to the left of X"),
#  Explanation(LF_17: 1, "A positive word is within 3 words to the right of X and A negative word is within 2 words to the left of Z"),
#  Explanation(LF_18: 1, "A negative word is within 2 words to the left of Z"),
#  Explanation(LF_19: 1, "A negative word is within 2 words to the left of Z"),
#  Explanation(LF_20: 1, "A negative word is within 2 words to the left of X"),
#  Explanation(LF_21: 1, "A negative word is within 2 words to the left of X"),
#  Explanation(LF_22: 1, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_23: 1, "A neutral word is within 3 words to the right of X"),
#  Explanation(LF_24: 1, "A negative word is within 2 words to the left of X and A negative word is within 2 words to the left of Y"),
#  Explanation(LF_25: 1, "A neutral word is within 2 words to the left of X and A negative word is within 2 words to the left of Z"),
#  Explanation(LF_26: 1, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_27: 1, "A negative word is within 2 words to the left of X and A negative word is within 2 words to the left of Z"),
#  Explanation(LF_28: 1, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_29: 1, "A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_30: 1, "A negative word is within 2 words to the left of Y"),
#  Explanation(LF_31: 1, "A negative word is within 2 words to the left of X"),
#  Explanation(LF_32: 1, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_33: 1, "A negative word is within 2 words to the left of X"),
#  Explanation(LF_34: 1, "A negative word is within 2 words to the left of Y"),
#  Explanation(LF_35: 1, "A negative word is within 2 words to the left of Y and A negative word is within 2 words to the left of Z"),
#  Explanation(LF_36: 1, "A negative word is within 2 words to the left of X and A negative word is within 2 words to the left of Y"),
#  Explanation(LF_37: 1, "A negative word is within 2 words to the left of Z"),
#  Explanation(LF_38: 1, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_39: 1, "A neutral word is within 3 words to the right of X and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_40: 1, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_41: 1, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_42: 1, "A negative word is within 2 words to the left of Z"),
#  Explanation(LF_43: 1, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_44: 1, "A neutral word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_45: 1, "A negative word is within 3 words to the right of X"),
#  Explanation(LF_46: 1, "A neutral word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_47: 1, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_48: 1, "A neutral word is within 3 words to the right of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_49: 1, "A positive word is within 2 words to the left of Y and A negative word is within 2 words to the left of Z"),
#  Explanation(LF_50: 1, "A negative word is within 2 words to the left of X"),
#  Explanation(LF_51: 1, "A negative word is within 2 words to the left of X"),
#  Explanation(LF_52: 1, "A negative word is within 2 words to the left of Y and A negative word is within 2 words to the left of Z"),
#  Explanation(LF_53: 1, "A negative word is within 2 words to the left of X"),
#  Explanation(LF_54: 1, "A negative word is within 2 words to the left of X and A negative word is within 2 words to the left of Y and A negative word is within 2 words to the left of Z"),
#  Explanation(LF_55: 1, "A positive word is within 2 words to the left of Z"),
#  Explanation(LF_56: 1, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_57: 1, "A negative word is within 3 words to the right of Y and A negative word is within 3 words to the right of Z"),
#  Explanation(LF_58: 1, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_59: 1, "A positive word is within 3 words to the right of Z"),
#  Explanation(LF_60: 1, "A negative word is within 2 words to the left of X and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_61: 1, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_62: 1, "A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_63: 1, "A negative word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_64: 1, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_65: 1, "A positive word is within 2 words to the left of Y and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_66: 1, "A negative word is within 2 words to the left of Z"),
#  Explanation(LF_67: 1, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_68: 1, "A neutral word is within 3 words to the right of X"),
#  Explanation(LF_69: 1, "A neutral word is within 3 words to the right of X and A positive word is within 2 words to the left of Y and A negative word is within 2 words to the left of Z"),
#  Explanation(LF_70: 1, "A negative word is within 2 words to the left of X and A negative word is within 2 words to the left of Z"),
#  Explanation(LF_71: 1, "A negative word is within 2 words to the left of X"),
#  Explanation(LF_72: 1, "A positive word is within 3 words to the right of Y"),
#  Explanation(LF_73: 1, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_74: 1, "A negative word is within 2 words to the left of Z"),
#  Explanation(LF_75: 1, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_76: 1, "A negative word is within 2 words to the left of Z"),
#  Explanation(LF_77: 1, "A negative word is within 2 words to the left of X"),
#  Explanation(LF_78: 1, "A neutral word is within 3 words to the right of X and A negative word is within 3 words to the right of Y and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_79: 1, "A positive word is within 2 words to the left of Y"),
#  Explanation(LF_80: 1, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_81: 1, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_82: 1, "A neutral word is within 2 words to the left of Y and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_83: 1, "A negative word is within 2 words to the left of X and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_84: 1, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_85: 1, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_86: 1, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_87: 1, "A neutral word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_88: 1, "A negative word is within 2 words to the left of Z"),
#  Explanation(LF_89: 1, "A negative word is within 2 words to the left of X"),
#  Explanation(LF_90: 1, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_91: 1, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_92: 1, "A negative word is within 3 words to the right of Z"),
#  Explanation(LF_93: 1, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_94: 1, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_95: 1, "A neutral word is within 3 words to the right of X"),
#  Explanation(LF_96: 1, "A negative word is within 2 words to the left of X"),
#  Explanation(LF_97: 1, "A negative word is within 2 words to the left of X"),
#  Explanation(LF_98: 1, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_99: 2, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_100: 2, "A positive word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_101: 2, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_102: 2, "A neutral word is within 3 words to the right of X and A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_103: 2, "A negative word is within 3 words to the right of X and A neutral word is within 2 words to the left of Y and A negative word is within 3 words to the right of Z"),
#  Explanation(LF_104: 2, "A neutral word is within 3 words to the right of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_105: 2, "A neutral word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_106: 2, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_107: 2, "A positive word is within 2 words to the left of Y"),
#  Explanation(LF_108: 2, "A positive word is within 3 words to the right of Y"),
#  Explanation(LF_109: 2, "A positive word is within 3 words to the right of X"),
#  Explanation(LF_110: 2, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_111: 2, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_112: 2, "A negative word is within 2 words to the left of X and A positive word is within 3 words to the right of Y"),
#  Explanation(LF_113: 2, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_114: 2, "A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_115: 2, "A positive word is within 3 words to the right of Y and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_116: 2, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_117: 2, "A neutral word is within 3 words to the right of X and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_118: 2, "A positive word is within 3 words to the right of Z"),
#  Explanation(LF_119: 2, "A neutral word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_120: 2, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_121: 2, "A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_122: 2, "A neutral word is within 3 words to the right of X and A neutral word is within 3 words to the right of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_123: 2, "A positive word is within 3 words to the right of X"),
#  Explanation(LF_124: 2, "A positive word is within 2 words to the left of Y"),
#  Explanation(LF_125: 2, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_126: 2, "A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_127: 2, "A positive word is within 3 words to the right of X and A neutral word is within 3 words to the right of Y and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_128: 2, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_129: 2, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_130: 2, "A neutral word is within 3 words to the right of X and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_131: 2, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_132: 2, "A negative word is within 3 words to the right of Y"),
#  Explanation(LF_133: 2, "A neutral word is within 2 words to the left of X and A negative word is within 2 words to the left of Y and A negative word is within 2 words to the left of Z"),
#  Explanation(LF_134: 2, "A positive word is within 3 words to the right of Z"),
#  Explanation(LF_135: 2, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_136: 2, "A positive word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_137: 2, "A positive word is within 2 words to the left of X and A negative word is within 3 words to the right of Y"),
#  Explanation(LF_138: 2, "A positive word is within 2 words to the left of X and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_139: 2, "A neutral word is within 2 words to the left of X and A negative word is within 2 words to the left of Z"),
#  Explanation(LF_140: 2, "A negative word is within 2 words to the left of X and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_141: 2, "A positive word is within 3 words to the right of Z"),
#  Explanation(LF_142: 2, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_143: 2, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_144: 2, "A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_145: 2, "A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_146: 2, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_147: 2, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_148: 2, "A negative word is within 2 words to the left of Y"),
#  Explanation(LF_149: 2, "A positive word is within 3 words to the right of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_150: 2, "A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_151: 2, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_152: 2, "A positive word is within 3 words to the right of Y and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_153: 2, "A positive word is within 3 words to the right of X and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_154: 2, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_155: 2, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_156: 2, "A negative word is within 2 words to the left of Y"),
#  Explanation(LF_157: 2, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_158: 2, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_159: 2, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_160: 2, "A neutral word is within 2 words to the left of Y and A negative word is within 3 words to the right of Z"),
#  Explanation(LF_161: 2, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_162: 2, "A neutral word is within 2 words to the left of Y and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_163: 2, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_164: 2, "A neutral word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_165: 2, "A positive word is within 3 words to the right of X"),
#  Explanation(LF_166: 2, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_167: 2, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_168: 2, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_169: 2, "A neutral word is within 3 words to the right of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_170: 2, "A negative word is within 2 words to the left of X and A negative word is within 2 words to the left of Y"),
#  Explanation(LF_171: 2, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_172: 2, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_173: 2, "A neutral word is within 2 words to the left of X and A negative word is within 2 words to the left of Y"),
#  Explanation(LF_174: 2, "A neutral word is within 3 words to the right of Y and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_175: 2, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_176: 2, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_177: 2, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_178: 2, "A neutral word is within 2 words to the left of X and A positive word is within 3 words to the right of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_179: 2, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_180: 2, "A positive word is within 2 words to the left of X and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_181: 2, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_182: 2, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_183: 2, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_184: 2, "A positive word is within 2 words to the left of X and A negative word is within 2 words to the left of Y and A negative word is within 2 words to the left of Z"),
#  Explanation(LF_185: 2, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_186: 2, "A neutral word is within 2 words to the left of X and A negative word is within 2 words to the left of Y and A negative word is within 2 words to the left of Z"),
#  Explanation(LF_187: 2, "A positive word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_188: 2, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_189: 2, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_190: 2, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_191: 2, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_192: 2, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_193: 2, "A neutral word is within 3 words to the right of X and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_194: 2, "A neutral word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_195: 2, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_196: 2, "A positive word is within 2 words to the left of X and A negative word is within 2 words to the left of Y"),
#  Explanation(LF_197: 2, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_198: 2, "A negative word is within 2 words to the left of X and A negative word is within 2 words to the left of Y"),
#  Explanation(LF_199: 2, "A positive word is within 3 words to the right of Y"),
#  Explanation(LF_200: 2, "A neutral word is within 3 words to the right of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_201: 2, "A negative word is within 2 words to the left of X and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_202: 2, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_203: 2, "A negative word is within 3 words to the right of Y and A negative word is within 2 words to the left of Z"),
#  Explanation(LF_204: 2, "A neutral word is within 3 words to the right of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_205: 2, "A neutral word is within 3 words to the right of Y and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_206: 2, "A negative word is within 2 words to the left of X and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_207: 2, "A negative word is within 3 words to the right of Y"),
#  Explanation(LF_208: 2, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_209: 2, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_210: 2, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_211: 2, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_212: 2, "A neutral word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_213: 2, "A negative word is within 2 words to the left of Y"),
#  Explanation(LF_214: 2, "A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_215: 2, "A negative word is within 3 words to the right of Y"),
#  Explanation(LF_216: 3, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_217: 3, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_218: 3, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_219: 3, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_220: 3, "A positive word is within 2 words to the left of X and A neutral word is within 3 words to the right of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_221: 3, "A neutral word is within 2 words to the left of X and A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_222: 3, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_223: 3, "A positive word is within 2 words to the left of X and A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_224: 3, "A positive word is within 3 words to the right of X"),
#  Explanation(LF_225: 3, "A neutral word is within 3 words to the right of X"),
#  Explanation(LF_226: 3, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_227: 3, "A neutral word is within 3 words to the right of X and A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_228: 3, "A positive word is within 3 words to the right of X"),
#  Explanation(LF_229: 3, "A negative word is within 2 words to the left of X"),
#  Explanation(LF_230: 3, "A positive word is within 2 words to the left of Y"),
#  Explanation(LF_231: 3, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_232: 3, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_233: 3, "A positive word is within 2 words to the left of Y"),
#  Explanation(LF_234: 3, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_235: 3, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_236: 3, "A positive word is within 2 words to the left of Z"),
#  Explanation(LF_237: 3, "A neutral word is within 3 words to the right of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_238: 3, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_239: 3, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_240: 3, "A positive word is within 3 words to the right of Y"),
#  Explanation(LF_241: 3, "A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_242: 3, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_243: 3, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_244: 3, "A positive word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_245: 3, "A positive word is within 3 words to the right of Y"),
#  Explanation(LF_246: 3, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_247: 3, "A positive word is within 2 words to the left of Y"),
#  Explanation(LF_248: 3, "A positive word is within 3 words to the right of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_249: 3, "A neutral word is within 3 words to the right of X and A neutral word is within 3 words to the right of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_250: 3, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_251: 3, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_252: 3, "A positive word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_253: 3, "A neutral word is within 3 words to the right of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_254: 3, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_255: 3, "A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_256: 3, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_257: 3, "A neutral word is within 2 words to the left of Y and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_258: 3, "A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_259: 3, "A positive word is within 3 words to the right of Y"),
#  Explanation(LF_260: 3, "A positive word is within 3 words to the right of Y and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_261: 3, "A positive word is within 2 words to the left of X and A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_262: 3, "A positive word is within 2 words to the left of Y"),
#  Explanation(LF_263: 3, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_264: 3, "A positive word is within 3 words to the right of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_265: 3, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_266: 3, "A neutral word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_267: 3, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_268: 3, "A positive word is within 3 words to the right of X and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_269: 3, "A neutral word is within 2 words to the left of X and A positive word is within 3 words to the right of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_270: 3, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_271: 3, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_272: 3, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_273: 3, "A positive word is within 3 words to the right of X and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_274: 3, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_275: 3, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_276: 3, "A negative word is within 3 words to the right of Y and A negative word is within 3 words to the right of Z"),
#  Explanation(LF_277: 3, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_278: 3, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_279: 3, "A neutral word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_280: 3, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_281: 3, "A positive word is within 2 words to the left of X and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_282: 3, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_283: 3, "A neutral word is within 3 words to the right of X"),
#  Explanation(LF_284: 3, "A positive word is within 3 words to the right of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_285: 3, "A neutral word is within 3 words to the right of X and A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_286: 3, "A neutral word is within 2 words to the left of Y and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_287: 3, "A positive word is within 2 words to the left of Z"),
#  Explanation(LF_288: 3, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_289: 3, "A neutral word is within 2 words to the left of X and A positive word is within 2 words to the left of Y and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_290: 3, "A negative word is within 2 words to the left of X"),
#  Explanation(LF_291: 3, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_292: 3, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_293: 3, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_294: 3, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_295: 3, "A neutral word is within 2 words to the left of X and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_296: 3, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_297: 3, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_298: 3, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_299: 3, "A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_300: 3, "A positive word is within 3 words to the right of X"),
#  Explanation(LF_301: 3, "A positive word is within 2 words to the left of X and A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_302: 3, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_303: 3, "A negative word is within 3 words to the right of X"),
#  Explanation(LF_304: 3, "A negative word is within 3 words to the right of X and A neutral word is within 3 words to the right of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_305: 3, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_306: 3, "A neutral word is within 2 words to the left of X and A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_307: 3, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_308: 3, "A positive word is within 3 words to the right of Z"),
#  Explanation(LF_309: 3, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_310: 3, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_311: 3, "A positive word is within 3 words to the right of Z"),
#  Explanation(LF_312: 3, "A neutral word is within 2 words to the left of X and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_313: 3, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_314: 3, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_315: 3, "A positive word is within 2 words to the left of Y"),
#  Explanation(LF_316: 3, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_317: 3, "A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_318: 3, "A positive word is within 3 words to the right of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_319: 3, "A positive word is within 2 words to the left of X and A negative word is within 2 words to the left of Y"),
#  Explanation(LF_320: 3, "A neutral word is within 2 words to the left of X and A positive word is within 2 words to the left of Y and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_321: 3, "A positive word is within 2 words to the left of Y and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_322: 3, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_323: 3, "A neutral word is within 3 words to the right of X and A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_324: 3, "A neutral word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_325: 3, "A neutral word is within 2 words to the left of X and A neutral word is within 3 words to the right of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_326: 3, "A positive word is within 3 words to the right of Y"),
#  Explanation(LF_327: 3, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_328: 3, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_329: 3, "A positive word is within 3 words to the right of Z"),
#  Explanation(LF_330: 3, "A positive word is within 2 words to the left of Y and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_331: 3, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_332: 3, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_333: 4, "A positive word is within 2 words to the left of X and A neutral word is within 3 words to the right of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_334: 4, "A positive word is within 3 words to the right of Y"),
#  Explanation(LF_335: 4, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_336: 4, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_337: 4, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_338: 4, "A neutral word is within 2 words to the left of X and A neutral word is within 3 words to the right of Y and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_339: 4, "A neutral word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_340: 4, "A neutral word is within 2 words to the left of X and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_341: 4, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_342: 4, "A positive word is within 2 words to the left of Z"),
#  Explanation(LF_343: 4, "A neutral word is within 2 words to the left of X and A positive word is within 3 words to the right of Y"),
#  Explanation(LF_344: 4, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_345: 4, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_346: 4, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_347: 4, "A positive word is within 2 words to the left of Z"),
#  Explanation(LF_348: 4, "A positive word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_349: 4, "A positive word is within 3 words to the right of X and A neutral word is within 3 words to the right of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_350: 4, "A neutral word is within 3 words to the right of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_351: 4, "A neutral word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_352: 4, "A positive word is within 2 words to the left of Z"),
#  Explanation(LF_353: 4, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_354: 4, "A neutral word is within 2 words to the left of X and A positive word is within 3 words to the right of Y and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_355: 4, "A positive word is within 2 words to the left of X and A positive word is within 3 words to the right of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_356: 4, "A neutral word is within 3 words to the right of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_357: 4, "A positive word is within 3 words to the right of Y"),
#  Explanation(LF_358: 4, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_359: 4, "A neutral word is within 3 words to the right of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_360: 4, "A neutral word is within 2 words to the left of X and A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_361: 4, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_362: 4, "A positive word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_363: 4, "A positive word is within 2 words to the left of Z"),
#  Explanation(LF_364: 4, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_365: 4, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_366: 4, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_367: 4, "A positive word is within 2 words to the left of X and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_368: 4, "A positive word is within 3 words to the right of Y and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_369: 4, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_370: 4, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_371: 4, "A negative word is within 2 words to the left of Z"),
#  Explanation(LF_372: 4, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_373: 4, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_374: 4, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_375: 4, "A neutral word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_376: 4, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_377: 4, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_378: 4, "A neutral word is within 2 words to the left of X and A positive word is within 2 words to the left of Y and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_379: 4, "A positive word is within 2 words to the left of Z"),
#  Explanation(LF_380: 4, "A positive word is within 2 words to the left of X and A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_381: 4, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_382: 4, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_383: 4, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_384: 4, "A positive word is within 2 words to the left of Z"),
#  Explanation(LF_385: 4, "A positive word is within 3 words to the right of Z"),
#  Explanation(LF_386: 4, "A positive word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_387: 4, "A neutral word is within 2 words to the left of X and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_388: 4, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_389: 4, "A positive word is within 2 words to the left of Z"),
#  Explanation(LF_390: 4, "A positive word is within 3 words to the right of Y and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_391: 4, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_392: 4, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_393: 4, "A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_394: 4, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_395: 4, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_396: 4, "A positive word is within 3 words to the right of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_397: 4, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_398: 4, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_399: 4, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_400: 4, "A positive word is within 2 words to the left of Z"),
#  Explanation(LF_401: 4, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_402: 4, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_403: 4, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_404: 4, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_405: 4, "A neutral word is within 2 words to the left of X and A negative word is within 2 words to the left of Y"),
#  Explanation(LF_406: 4, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_407: 4, "A neutral word is within 3 words to the right of Y and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_408: 4, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_409: 4, "A neutral word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_410: 4, "A neutral word is within 2 words to the left of Y and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_411: 4, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_412: 4, "A positive word is within 3 words to the right of Y and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_413: 4, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_414: 4, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_415: 4, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_416: 4, "A positive word is within 2 words to the left of X and A positive word is within 3 words to the right of Y and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_417: 4, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_418: 4, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_419: 4, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_420: 4, "A positive word is within 3 words to the right of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_421: 4, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_422: 4, "A positive word is within 2 words to the left of Y and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_423: 4, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_424: 4, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_425: 4, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_426: 4, "A positive word is within 3 words to the right of Z"),
#  Explanation(LF_427: 4, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_428: 4, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_429: 4, "A neutral word is within 3 words to the right of X and A positive word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_430: 4, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_431: 4, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
# ...
#  Explanation(LF_453: 4, "A positive word is within 2 words to the left of X and A negative word is within 3 words to the right of Y and A negative word is within 2 words to the left of Z"),
#  Explanation(LF_454: 4, "A positive word is within 3 words to the right of Z"),
#  Explanation(LF_455: 4, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_456: 4, "A neutral word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_457: 4, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_458: 4, "A positive word is within 3 words to the right of Y and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_459: 4, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_460: 4, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_461: 4, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_462: 4, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_463: 4, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_464: 4, "A neutral word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_465: 5, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_466: 5, "A positive word is within 2 words to the left of Z"),
#  Explanation(LF_467: 5, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_468: 5, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_469: 5, "A neutral word is within 3 words to the right of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_470: 5, "A positive word is within 3 words to the right of Y and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_471: 5, "A neutral word is within 2 words to the left of X and A positive word is within 3 words to the right of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_472: 5, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_473: 5, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_474: 5, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_475: 5, "A positive word is within 3 words to the right of X"),
#  Explanation(LF_476: 5, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_477: 5, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_478: 5, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_479: 5, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_480: 5, "A neutral word is within 2 words to the left of X and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_481: 5, "A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_482: 5, "A positive word is within 3 words to the right of X and A positive word is within 2 words to the left of Y and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_483: 5, "A positive word is within 2 words to the left of X and A positive word is within 3 words to the right of Y"),
#  Explanation(LF_484: 5, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_485: 5, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_486: 5, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_487: 5, "A positive word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_488: 5, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_489: 5, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_490: 5, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_491: 5, "A positive word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_492: 5, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_493: 5, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_494: 5, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_495: 5, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_496: 5, "A positive word is within 2 words to the left of Y"),
#  Explanation(LF_497: 5, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_498: 5, "A positive word is within 2 words to the left of Y"),
#  Explanation(LF_499: 5, "A positive word is within 3 words to the right of Y"),
#  Explanation(LF_500: 5, "A positive word is within 2 words to the left of Z"),
#  Explanation(LF_501: 5, "A positive word is within 2 words to the left of X and A neutral word is within 3 words to the right of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_502: 5, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_503: 5, "A positive word is within 2 words to the left of Y"),
#  Explanation(LF_504: 5, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_505: 5, "A positive word is within 2 words to the left of Z"),
#  Explanation(LF_506: 5, "A neutral word is within 2 words to the left of X and A positive word is within 3 words to the right of Y"),
#  Explanation(LF_507: 5, "A neutral word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_508: 5, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_509: 5, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_510: 5, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_511: 5, "A positive word is within 3 words to the right of Y"),
#  Explanation(LF_512: 5, "A positive word is within 2 words to the left of Y"),
#  Explanation(LF_513: 5, "A positive word is within 3 words to the right of Y"),
#  Explanation(LF_514: 5, "A positive word is within 2 words to the left of Z"),
#  Explanation(LF_515: 5, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_516: 5, "A neutral word is within 2 words to the left of X and A positive word is within 3 words to the right of Y and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_517: 5, "A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_518: 5, "A neutral word is within 2 words to the left of X and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_519: 5, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_520: 5, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_521: 5, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_522: 5, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_523: 5, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_524: 5, "A positive word is within 2 words to the left of X and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_525: 5, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_526: 5, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_527: 5, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_528: 5, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_529: 5, "A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_530: 5, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_531: 5, "A positive word is within 2 words to the left of X and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_532: 5, "A positive word is within 2 words to the left of Z"),
#  Explanation(LF_533: 5, "A positive word is within 3 words to the right of Y"),
#  Explanation(LF_534: 5, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_535: 5, "A negative word is within 2 words to the left of X and A positive word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_536: 5, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_537: 5, "A positive word is within 2 words to the left of X and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_538: 5, "A positive word is within 2 words to the left of Z"),
#  Explanation(LF_539: 5, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_540: 5, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_541: 5, "A positive word is within 2 words to the left of Z"),
#  Explanation(LF_542: 5, "A positive word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_543: 5, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_544: 5, "A positive word is within 2 words to the left of X and A neutral word is within 3 words to the right of Y"),
#  Explanation(LF_545: 5, "A positive word is within 2 words to the left of Z"),
#  Explanation(LF_546: 5, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_547: 5, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_548: 5, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_549: 5, "A positive word is within 2 words to the left of Z"),
#  Explanation(LF_550: 5, "A neutral word is within 2 words to the left of Y and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_551: 5, "A positive word is within 3 words to the right of Y"),
#  Explanation(LF_552: 5, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_553: 5, "A positive word is within 2 words to the left of Z"),
#  Explanation(LF_554: 5, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_555: 5, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_556: 5, "A neutral word is within 3 words to the right of X and A neutral word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_557: 5, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_558: 5, "A neutral word is within 3 words to the right of Y and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_559: 5, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_560: 5, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_561: 5, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_562: 5, "A positive word is within 2 words to the left of X and A positive word is within 3 words to the right of Z"),
#  Explanation(LF_563: 5, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_564: 5, "A neutral word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_565: 5, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_566: 5, "A positive word is within 2 words to the left of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_567: 5, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_568: 5, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_569: 5, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_570: 5, "A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_571: 5, "A positive word is within 3 words to the right of Z"),
#  Explanation(LF_572: 5, "A positive word is within 2 words to the left of Z"),
#  Explanation(LF_573: 5, "A neutral word is within 2 words to the left of X"),
#  Explanation(LF_574: 5, "A positive word is within 2 words to the left of Y"),
#  Explanation(LF_575: 5, "A neutral word is within 2 words to the left of X and A positive word is within 2 words to the left of Y and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_576: 5, "A positive word is within 3 words to the right of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_577: 5, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_578: 5, "A positive word is within 2 words to the left of X and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_579: 5, "A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_580: 5, "A neutral word is within 2 words to the left of X and A positive word is within 3 words to the right of Y"),
#  Explanation(LF_581: 5, "A neutral word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z"),
#  Explanation(LF_582: 5, "A positive word is within 2 words to the left of Y and A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_583: 5, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_584: 5, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_585: 5, "A positive word is within 3 words to the right of Z"),
#  Explanation(LF_586: 5, "A positive word is within 3 words to the right of Z"),
#  Explanation(LF_587: 5, "A positive word is within 3 words to the right of X"),
#  Explanation(LF_588: 5, "A positive word is within 3 words to the right of Y and A positive word is within 2 words to the left of Z"),
#  Explanation(LF_589: 5, "A positive word is within 2 words to the left of X and A neutral word is within 2 words to the left of Y"),
#  Explanation(LF_590: 5, "A positive word is within 2 words to the left of Y"),
#  Explanation(LF_591: 5, "A positive word is within 2 words to the left of X and A positive word is within 2 words to the left of Y"),
#  Explanation(LF_592: 5, "A neutral word is within 3 words to the right of Z"),
#  Explanation(LF_593: 5, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_594: 5, "A positive word is within 2 words to the left of X"),
#  Explanation(LF_595: 5, "A neutral word is within 2 words to the left of Y and A neutral word is within 2 words to the left of Z")]
